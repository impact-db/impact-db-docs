# %% [raw]
# .. toctree::
#    :maxdepth: 2
#    :caption: Contents:
#
#    home <self>
#    description
#    test

# %% [markdown]
# # ImpactDB Experimental Data Upload Demo

# %%
import json
import requests
import pandas as pd

from IPython.core.display import HTML

custom_css = """
<style>
    div {
        max-width: 1080px;
        overflow-x: auto;
        display: block;
    }
</style>
"""

display(HTML(custom_css))
# Out:
# <style>
#     div {
#         max-width: 1080px;
#         overflow-x: auto;
#         display: block;
#     }
# </style>

# %% [markdown]
# ### Load experimental data from a .json file
# This example data is from a paper in [ImpactDB](https://impact-database.com/paper/rhodosporidium/production-of-galactitol-from-galactose-by-the-oleaginous-yeast-rhodosporidium-toruloides-ifo0880)

# %%
with open('json_template.json', 'r') as f:
    experimental_data = f.read()

experimental_data = json.loads(experimental_data)
experimental_data
# Out:
# [{'geneticNotes': '',
#   'heterologousGenes': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'integrationSites': '',
#   'nitrogenLevel': 'sufficient',
#   'media': 'YPD',
#   'substrateConc1': '20',
#   'substrateConc2': '',
#   'vessel': 'shake flask',
#   'yield': '0.16',
#   'titer': '3.2',
#   'pH': '',
#   'maximumRate': '0.0267',
#   'temperature': '30',
#   'substrate1': 'galactose',
#   'substrate2': '',
#   'geneIds': '',
#   'promoters': '',
#   'parentStrain': 'IFO0880',
#   'strain': '',
#   'averageRate': '0.0267',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'directedEvolution': False,
#   'originSpecies': '',
#   'volume': '0.050',
#   'engineeredStrain': '',
#   'knockedOutGenes': '',
#   'oxygenLevel': 'sufficient',
#   'species': 'Rhodosporidium',
#   'overexpressedGenes': '',
#   'time': '120',
#   'bioprocessNotes': ''},
#  {'geneticNotes': '',
#   'heterologousGenes': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'integrationSites': '',
#   'nitrogenLevel': 'sufficient',
#   'substrateConc1': '40',
#   'media': 'YPD',
#   'substrateConc2': '',
#   'vessel': 'shake flask',
#   'yield': '0.21',
#   'maximumRate': '0.07',
#   'pH': '',
#   'temperature': '30',
#   'titer': '8.4',
#   'substrate1': 'galactose',
#   'substrate2': '',
#   'geneIds': '',
#   'promoters': '',
#   'parentStrain': 'IFO0880',
#   'strain': '',
#   'averageRate': '0.07',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'directedEvolution': False,
#   'originSpecies': '',
#   'volume': '0.050',
#   'engineeredStrain': '',
#   'knockedOutGenes': '',
#   'species': 'Rhodosporidium',
#   'oxygenLevel': 'sufficient',
#   'overexpressedGenes': '',
#   'time': '120',
#   'bioprocessNotes': ''},
#  {'geneticNotes': '',
#   'heterologousGenes': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'integrationSites': '',
#   'nitrogenLevel': 'sufficient',
#   'media': 'YPD',
#   'substrateConc1': '60',
#   'substrateConc2': '',
#   'yield': '0.1367',
#   'vessel': 'shake flask',
#   'titer': '8.2',
#   'maximumRate': '0.0854',
#   'temperature': '30',
#   'pH': '',
#   'substrate1': 'galactose',
#   'substrate2': '',
#   'geneIds': '',
#   'promoters': '',
#   'parentStrain': 'IFO0880',
#   'averageRate': '0.0854',
#   'strain': '',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'originSpecies': '',
#   'directedEvolution': False,
#   'volume': '0.050',
#   'knockedOutGenes': '',
#   'engineeredStrain': '',
#   'species': 'Rhodosporidium',
#   'oxygenLevel': 'sufficient',
#   'overexpressedGenes': '',
#   'time': '96',
#   'bioprocessNotes': ''},
#  {'geneticNotes': '',
#   'heterologousGenes': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'integrationSites': '',
#   'nitrogenLevel': 'limited',
#   'media': '.75g/L yeast extract, 1.7 g/L YNB, 0.1g/L ammonium sulfate',
#   'substrateConc1': '20',
#   'substrateConc2': '',
#   'yield': '0.15',
#   'vessel': 'shake flask',
#   'pH': '5.6',
#   'maximumRate': '0.0208',
#   'temperature': '30',
#   'titer': '3.0',
#   'substrate1': 'galactose',
#   'substrate2': '',
#   'geneIds': '',
#   'promoters': '',
#   'parentStrain': 'IFO0880',
#   'averageRate': '0.0208',
#   'strain': '',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'directedEvolution': False,
#   'originSpecies': '',
#   'volume': '0.050',
#   'engineeredStrain': '',
#   'knockedOutGenes': '',
#   'species': 'Rhodosporidium',
#   'oxygenLevel': 'sufficient',
#   'overexpressedGenes': '',
#   'time': '144',
#   'bioprocessNotes': ''},
#  {'geneticNotes': '',
#   'heterologousGenes': '',
#   'integrationSites': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'nitrogenLevel': 'limited',
#   'media': '.75g/L yeast extract, 1.7 g/L YNB, 0.1g/L ammonium sulfate',
#   'substrateConc1': '40',
#   'substrateConc2': '',
#   'yield': '0.13',
#   'vessel': 'shake flask',
#   'temperature': '30',
#   'titer': '5.2',
#   'maximumRate': '0.0361',
#   'pH': '5.6',
#   'substrate1': 'galactose',
#   'geneIds': '',
#   'substrate2': '',
#   'promoters': '',
#   'parentStrain': 'IFO0880',
#   'strain': '',
#   'averageRate': '0.0361',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'originSpecies': '',
#   'directedEvolution': False,
#   'volume': '0.050',
#   'knockedOutGenes': '',
#   'engineeredStrain': '',
#   'oxygenLevel': 'sufficient',
#   'species': 'Rhodosporidium',
#   'overexpressedGenes': '',
#   'time': '144',
#   'bioprocessNotes': ''},
#  {'geneticNotes': '',
#   'heterologousGenes': '',
#   'sourceEmail': 'jondhudson.rpi@gmail.com',
#   'integrationSites': '',
#   'nitrogenLevel': 'limited',
#   'media': '.75g/L yeast extract, 1.7 g/L YNB, 0.1g/L ammonium sulfate',
#   'substrateConc1': '60',
#   'substrateConc2': '',
#   'vessel': 'shake flask',
#   'yield': '0.1233',
#   'titer': '7.4',
#   'maximumRate': '0.0385',
#   'temperature': '30',
#   'pH': '5.6',
#   'substrate1': 'galactose',
#   'substrate2': '',
#   'geneIds': '',
#   'parentStrain': 'IFO0880',
#   'promoters': '',
#   'strain': '',
#   'averageRate': '0.0385',
#   'product': 'galactitol',
#   'optimizedCodons': '',
#   'geneNames': '',
#   'directedEvolution': False,
#   'originSpecies': '',
#   'volume': '0.050',
#   'engineeredStrain': '',
#   'knockedOutGenes': '',
#   'species': 'Rhodosporidium',
#   'oxygenLevel': 'sufficient',
#   'overexpressedGenes': '',
#   'time': '192',
#   'bioprocessNotes': ''}]

# %% [markdown]
# ### Manually define bioprocess data

# %%
DataGPT = [
  {
    "geneticNotes": "",
    "heterologousGenes": "",
    "sourceEmail": "zhengyang.xiao99@gmail.com",
    "integrationSites": "",
    # "nitrogenLevel": "",
    "nitrogenLevel": "sufficient",
    "media": "rich",
    "substrateConc1": "0",
    "substrateConc2": "",
    "vessel": "batch reactor",
    "yield": "",
    "titer": "0.02764",
    "pH": "7.4",
    "maximumRate": "",
    "temperature": "30",
    "substrate1": "Waste hydrolysate",
    "substrate2": "",
    "geneIds": "",
    "promoters": "",
    # "parentStrain": "",
    "parentStrain": "temp name",
    "strain": "Rhodosporidium toruloides",
    "averageRate": "",
    "product": "1,8-cineole",
    "optimizedCodons": "",
    "geneNames": "",
    "directedEvolution": False,
    "originSpecies": "",
    "volume": "2",
    "engineeredStrain": "",
    "knockedOutGenes": "",
    "oxygenLevel": "sufficient",
    "species": "Rhodosporidium",
    "overexpressedGenes": "",
    "time": "168",
    "bioprocessNotes": ""
  }
]

# %% [markdown]
# ### Load data from an excel file

# %%
# load excel data into a dataframe
excel_file = pd.read_excel('excel_template.xlsx')

# replace NaN with empty strings
excel_file = excel_file.fillna('')
display(excel_file.head())

# convert dataframe to json string
json_str = excel_file.to_json(orient='records')
print(type(json_str), json_str)

# convert json string to json object
json_obj = json.loads(json_str)
print(type(json_obj), json_obj)
# Out:
#                      species strain engineeredStrain parentStrain product  \
# 0  Rhodosporidium toruloides                                  ABC   lipid
# 1  Rhodosporidium toruloides                                  ABC   lipid
# 2  Rhodosporidium toruloides                                  ABC   lipid
# 3  Rhodosporidium toruloides                                  ABC   lipid
# 4  Rhodosporidium toruloides                                  ABC   lipid
#
#    titer averageRate maximumRate yield  volume  ... overexpressedGenes  \
# 0  7.769                                   100  ...
# 1  6.769                                   100  ...
# 2  4.638                                   100  ...
# 3  2.436                                   100  ...
# 4  1.761                                   100  ...
#
#   heterologousGenes  promoters integrationSites originSpecies optimizedCodons  \
# 0
# 1
# 2
# 3
# 4
#
#    directedEvolution                 sourceEmail geneticNotes bioprocessNotes
# 0                     zhengyang.xiao99@gmail.com
# 1                     zhengyang.xiao99@gmail.com
# 2                     zhengyang.xiao99@gmail.com
# 3                     zhengyang.xiao99@gmail.com
# 4                     zhengyang.xiao99@gmail.com
#
# [5 rows x 34 columns]
# <class 'str'> [{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":7.769,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"sufficient","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhengyang.xiao99@gmail.com","geneticNotes":"","bioprocessNotes":""},{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":6.769,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"CIN = 40: 1","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhengyang.xiao99@gmail.com","geneticNotes":"","bioprocessNotes":""},{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":4.638,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"C\/N=80:1","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhengyang.xiao99@gmail.com","geneticNotes":"","bioprocessNotes":""},{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":2.436,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"C\/N=160:1","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhengyang.xiao99@gmail.com","geneticNotes":"","bioprocessNotes":""},{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":1.761,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"C\/N =200:1","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhengyang.xiao99@gmail.com","geneticNotes":"","bioprocessNotes":""},{"species":"Rhodosporidium toruloides","strain":"","engineeredStrain":"","parentStrain":"ABC","product":"lipid","titer":0.924,"averageRate":"","maximumRate":"","yield":"","volume":100,"vessel":"shake flask","substrate1":"sucrose","substrateConc1":40,"substrate2":"","substrateConc2":"","media":"defined","time":24,"oxygenLevel":"sufficient","nitrogenLevel":"C\/N = infinity","pH":"","temperature":28,"geneIds":"","geneNames":"","knockedOutGenes":"","overexpressedGenes":"","heterologousGenes":"","promoters":"","integrationSites":"","originSpecies":"","optimizedCodons":"","directedEvolution":"","sourceEmail":"zhe ...
# <class 'list'> [{'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 7.769, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40, 'substrate2': '', 'substrateConc2': '', 'media': 'defined', 'time': 24, 'oxygenLevel': 'sufficient', 'nitrogenLevel': 'sufficient', 'pH': '', 'temperature': 28, 'geneIds': '', 'geneNames': '', 'knockedOutGenes': '', 'overexpressedGenes': '', 'heterologousGenes': '', 'promoters': '', 'integrationSites': '', 'originSpecies': '', 'optimizedCodons': '', 'directedEvolution': '', 'sourceEmail': 'zhengyang.xiao99@gmail.com', 'geneticNotes': '', 'bioprocessNotes': ''}, {'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 6.769, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40, 'substrate2': '', 'substrateConc2': '', 'media': 'defined', 'time': 24, 'oxygenLevel': 'sufficient', 'nitrogenLevel': 'CIN = 40: 1', 'pH': '', 'temperature': 28, 'geneIds': '', 'geneNames': '', 'knockedOutGenes': '', 'overexpressedGenes': '', 'heterologousGenes': '', 'promoters': '', 'integrationSites': '', 'originSpecies': '', 'optimizedCodons': '', 'directedEvolution': '', 'sourceEmail': 'zhengyang.xiao99@gmail.com', 'geneticNotes': '', 'bioprocessNotes': ''}, {'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 4.638, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40, 'substrate2': '', 'substrateConc2': '', 'media': 'defined', 'time': 24, 'oxygenLevel': 'sufficient', 'nitrogenLevel': 'C/N=80:1', 'pH': '', 'temperature': 28, 'geneIds': '', 'geneNames': '', 'knockedOutGenes': '', 'overexpressedGenes': '', 'heterologousGenes': '', 'promoters': '', 'integrationSites': '', 'originSpecies': '', 'optimizedCodons': '', 'directedEvolution': '', 'sourceEmail': 'zhengyang.xiao99@gmail.com', 'geneticNotes': '', 'bioprocessNotes': ''}, {'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 2.436, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40, 'substrate2': '', 'substrateConc2': '', 'media': 'defined', 'time': 24, 'oxygenLevel': 'sufficient', 'nitrogenLevel': 'C/N=160:1', 'pH': '', 'temperature': 28, 'geneIds': '', 'geneNames': '', 'knockedOutGenes': '', 'overexpressedGenes': '', 'heterologousGenes': '', 'promoters': '', 'integrationSites': '', 'originSpecies': '', 'optimizedCodons': '', 'directedEvolution': '', 'sourceEmail': 'zhengyang.xiao99@gmail.com', 'geneticNotes': '', 'bioprocessNotes': ''}, {'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 1.761, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40, 'substrate2': '', 'substrateConc2': '', 'media': 'defined', 'time': 24, 'oxygenLevel': 'sufficient', 'nitrogenLevel': 'C/N =200:1', 'pH': '', 'temperature': 28, 'geneIds': '', 'geneNames': '', 'knockedOutGenes': '', 'overexpressedGenes': '', 'heterologousGenes': '', 'promoters': '', 'integrationSites': '', 'originSpecies': '', 'optimizedCodons': '', 'directedEvolution': '', 'sourceEmail': 'zhengyang.xiao99@gmail.com', 'geneticNotes': '', 'bioprocessNotes': ''}, {'species': 'Rhodosporidium toruloides', 'strain': '', 'engineeredStrain': '', 'parentStrain': 'ABC', 'product': 'lipid', 'titer': 0.924, 'averageRate': '', 'maximumRate': '', 'yield': '', 'volume': 100, 'vessel': 'shake flask', 'substrate1': 'sucrose', 'substrateConc1': 40,  ...

# %%
url = 'https://us-central1-impact-db.cloudfunctions.net/uploadExperimentalData'

# local endpoint for testing
# url = 'http://localhost:5001/impact-db/us-central1/uploadExperimentalData'

data = {
    'species': 'yarrowia',
    'slug': '-ketoglutaric-acid-production-by-yarrowia-lipolytica-and-its-regulation',
    # 'experimentalData': json_obj, # data from excel file
    'experimentalData': DataGPT, # data from python object
    # 'experimentalData': experimental_data, # data from json file
}

headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, data=json.dumps(data), headers=headers)

print(response.text)
# Out:
# {"message":"Bad request. Papers with existing experimental data cannot be updated for now."}
